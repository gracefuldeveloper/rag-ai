# %%
import pandas as pd
import numpy as np
from langchain.schema import Document # LangChain Document 객체 리스트 형태로 변환
from langchain_community.document_loaders import UnstructuredExcelLoader

# %%
# !pip install unstructured

# %%
import nltk
# # nltk.download() # 실패
# nltk.download("averaged_perceptron_tagger") # 실패
# nltk.download("all") # 성공
# Out:
# [nltk_data] Downloading collection 'all'
# [nltk_data]    |
# [nltk_data]    | Downloading package abc to /Users/grace/nltk_data...
# [nltk_data]    |   Unzipping corpora/abc.zip.
# [nltk_data]    | Downloading package alpino to
# [nltk_data]    |     /Users/grace/nltk_data...
# [nltk_data]    |   Unzipping corpora/alpino.zip.
# [nltk_data]    | Downloading package averaged_perceptron_tagger to
# [nltk_data]    |     /Users/grace/nltk_data...
# [nltk_data]    |   Package averaged_perceptron_tagger is already up-
# [nltk_data]    |       to-date!
# [nltk_data]    | Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]    |     /Users/grace/nltk_data...
# [nltk_data]    |   Unzipping
# [nltk_data]    |       taggers/averaged_perceptron_tagger_eng.zip.
# [nltk_data]    | Downloading package averaged_perceptron_tagger_ru to
# [nltk_data]    |     /Users/grace/nltk_data...
# [nltk_data]    |   Unzipping
# [nltk_data]    |       taggers/averaged_perceptron_tagger_ru.zip.
# ...

# %%
# 엑셀로 로드했을 때
path = "/Users/grace/dev_grace/rag-ai/dataset/rag_xlsx_sample.xlsx"
loader = UnstructuredExcelLoader(path, mode="elements")
docs = loader.load()

docs
# Out:
# [Document(metadata={'source': '/Users/grace/dev_grace/rag-ai/dataset/rag_xlsx_sample.xlsx', 'file_directory': '/Users/grace/dev_grace/rag-ai/dataset', 'filename': 'rag_xlsx_sample.xlsx', 'last_modified': '2025-06-10T22:07:12', 'page_name': '시트1', 'page_number': 1, 'languages': ['kor'], 'filetype': 'application/vnd.openxmlformats-officedocument.spreadsheetml.sheet', 'category': 'Title', 'element_id': '88d56487474364561b1d77e074f06a91'}, page_content='(1) 약관 내 의학용어 순화'),
# ...

# %%
print(docs[1].metadata["text_as_html"])  # https://wikidocs.net/253710
# Out:
# <table border="1" class="dataframe">
#   <tbody>
#     <tr>
#       <td>용어</td>
#       <td>용어순화</td>
#       <td>용어</td>
#       <td>용어순화</td>
#     </tr>
#     <tr>
#       <td>경계성 종양</td>
#       <td>경계성종양 (악성과 양성의 중간 단계의 종양)</td>
#       <td>비적제술</td>
#       <td>비장절제술</td>
#     </tr>
#     <tr>
#       <td>상피내암</td>
#       <td>상피내암\n(암이 발생하였으나\n상피안에 국한하여\n아직 퍼지지 않은 암,\n제0기암)</td>
#       <td>악하선(종양)</td>
#       <td>턱밑샘(종양)</td>
#     </tr>
#   </tbody>
# </table>

# %%
from langchain_community.document_loaders import PyPDFLoader

# pdf 로 로드했을 때
path = "/Users/grace/dev_grace/rag-ai/dataset/rag_pdf_sample.pdf"
loader = PyPDFLoader(path)
docs_pdf = loader.load()

docs_pdf
# Out:
# [Document(metadata={'source': '/Users/grace/dev_grace/rag-ai/dataset/rag_pdf_sample.pdf', 'page': 0}, page_content='용어용어 순화용어용어 순화경계성 종양경계성종양(악성과 양성의 중간 단계의 종양) 비적제술비장절제술상피내암상피내암(암이 발생하였으나 상피안에  국한하여 아직 퍼지지 않은 암, 제0기암) 악하선(종양) 턱밑샘(종양)미세침흡인검사미세바늘흡인검사(가는 침으로 내용물과  세포를 뽑아내여 현미경으로 진단하는 검사법) 복막염복막염(배막염)적제절제(수술로 제거함)자궁경관봉축술자궁목성형술담석증담석증(쓸개돌증) 질탈수술질처짐증수술신부전증콩팥기능상실증형성술성형술갑상선갑상샘흉막수술가슴막수술신증후군신증후군(콩팥증후군)종격종양적출술종격동(세로칸)종양수술결석결석(돌) 식도이단술식도절단술농양농양(고름집) 치핵치질뇌전산화단층촬영뇌전산화단층촬영(CT)(장기이식에서)수용자(장기이식에서)받은 이제대혈제대혈(탯줄) 음낭수종물음낭증구강구강(입속) 자궁경관형성술자궁목성형술담낭증담남염(쓸개염) 자궁경관봉축술자궁목봉합술근/근염근육/근육염자궁탈수술자궁탈출증수술(자궁삐짐수술)점액종점액낭종두개머리뼈폐색폐색(막힘) 척수경막척수경질막경피경피(피부를 통한) 안검하수증눈꺼풀처짐증담석증담석증(쓸개돌증) 누방비강문합술눌물주머니코안연결술비중격코중격안와안화(눈확)상악골위턱뼈청신경종양청신경종양(속귀종양)관혈수술관혈수술(수술) 승모판승모판(왼방실판막)만성부비강염만성코곁굴염(부비동염)누소관형성술눈물소관(눈물길)성형술후두전적제술후두 전부절제술초자체유리체(액)흉곽형수술흉곽형수술(가슴성형술)홍제전후유착박리술홍채유리박리술심막심장막\n약관내 의학용어 순화')]

# %%
print(docs_pdf[0].metadata)
print(docs_pdf[0].page_content)
# Out:
# {'source': '/Users/grace/dev_grace/rag-ai/dataset/rag_pdf_sample.pdf', 'page': 0}
# 용어용어 순화용어용어 순화경계성 종양경계성종양(악성과 양성의 중간 단계의 종양) 비적제술비장절제술상피내암상피내암(암이 발생하였으나 상피안에  국한하여 아직 퍼지지 않은 암, 제0기암) 악하선(종양) 턱밑샘(종양)미세침흡인검사미세바늘흡인검사(가는 침으로 내용물과  세포를 뽑아내여 현미경으로 진단하는 검사법) 복막염복막염(배막염)적제절제(수술로 제거함)자궁경관봉축술자궁목성형술담석증담석증(쓸개돌증) 질탈수술질처짐증수술신부전증콩팥기능상실증형성술성형술갑상선갑상샘흉막수술가슴막수술신증후군신증후군(콩팥증후군)종격종양적출술종격동(세로칸)종양수술결석결석(돌) 식도이단술식도절단술농양농양(고름집) 치핵치질뇌전산화단층촬영뇌전산화단층촬영(CT)(장기이식에서)수용자(장기이식에서)받은 이제대혈제대혈(탯줄) 음낭수종물음낭증구강구강(입속) 자궁경관형성술자궁목성형술담낭증담남염(쓸개염) 자궁경관봉축술자궁목봉합술근/근염근육/근육염자궁탈수술자궁탈출증수술(자궁삐짐수술)점액종점액낭종두개머리뼈폐색폐색(막힘) 척수경막척수경질막경피경피(피부를 통한) 안검하수증눈꺼풀처짐증담석증담석증(쓸개돌증) 누방비강문합술눌물주머니코안연결술비중격코중격안와안화(눈확)상악골위턱뼈청신경종양청신경종양(속귀종양)관혈수술관혈수술(수술) 승모판승모판(왼방실판막)만성부비강염만성코곁굴염(부비동염)누소관형성술눈물소관(눈물길)성형술후두전적제술후두 전부절제술초자체유리체(액)흉곽형수술흉곽형수술(가슴성형술)홍제전후유착박리술홍채유리박리술심막심장막
# 약관내 의학용어 순화

# %%
print("test")
